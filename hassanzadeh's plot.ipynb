# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def plot(y,positive_probes=None):
    fig = plt.figure(figsize=(3,10))
    ax = fig.add_subplot(111)
    plt.scatter(x=[1 for _ in y],y=y,marker='_',s=13000,color='k')
    plt.xlabel('Low',fontsize=20)
    plt.ylabel('Probes ranked by predicted intensity',fontsize=20)
    plt.title('High',fontsize=20)
    plt.xlim([.97,1.03])
    if positive_probes is not None:
        ax.annotate("Positive Probes", fontsize=15,xy=(1.022,positive_probes[0]), 
                            xytext=(1.05,3),
                            arrowprops=dict(facecolor='k', shrink=0.05, 
                                            width=1, headwidth=5))
        for y in positive_probes[1:]:
            ax.annotate("", xy=(1.022,y), 
                                xytext=(1.05,3),
                                arrowprops=dict(facecolor='k', shrink=0.05, 
                                                width=1, headwidth=5))
    ax.set_xticks([])
    ax.set_yticks([])
    plt.show()
    return(None)

# %%
plot([1,2,2.2,2.5,3,3.1,3.11,3.23,3.25,3.3],positive_probes=[3.3,2.5,3.11])
